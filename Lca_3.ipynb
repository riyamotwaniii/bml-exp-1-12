# %% [markdown]
# <a href="https://colab.research.google.com/github/riyamotwaniii/bml-exp-1-12/blob/main/Lca_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

# Load dataset
df = pd.read_csv('/content/drive/My Drive/bml/Customers_Data.csv')

# %%
# Convert gender to numbers
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})
df=df[df['Gender'] ==1]


# Select features
X = df[['Gender','Age','Annual Income (k$)','Spending Score (1-100)']]

# Scale data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply K-Means
kmeans = KMeans(n_clusters=5, random_state=0)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# Plot clusters
plt.scatter(df['Annual Income (k$)'], df['Spending Score (1-100)'], c=df['Cluster'])
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Customer Segmentations- KMeans")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2364145033.py in <cell line: 0>()
#       1 # Convert gender to numbers
# ----> 2 df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})
#       3 df=df[df['Gender'] ==1]
#       4
#       5
#
# NameError: name 'df' is not defined
